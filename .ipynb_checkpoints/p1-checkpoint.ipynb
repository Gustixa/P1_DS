# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
directorio = "./docs/"

# %%
# Initialize an empty list to hold dataframes
dataframes = []

# Recorre todos los archivos en el directorio
for filename in os.listdir(directorio):
    if filename.endswith(".csv"):
        filepath = os.path.join(directorio, filename)
        # Lee cada archivo CSV omitiendo la primera fila
        df = pd.read_csv(filepath, skiprows=1)
        # Elimina columnas "Unnamed"
        df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
        # Agrega el dataframe a la lista
        dataframes.append(df)

# Concatena todos los dataframes en uno solo
combined_df = pd.concat(dataframes, ignore_index=True)

# Guarda el dataframe combinado en un nuevo archivo CSV
combined_df.to_csv('dataset.csv', index=False)

print("¡Archivos CSV combinados y limpios exitosamente!")
# Out:
# ¡Archivos CSV combinados y limpios exitosamente!

# %%
df = pd.read_csv("dataset.csv")

# %%
df
# Out:
#                                                  CODIGO DISTRITO  \
# 0                                         21-01-0101-46   21-002
# 1                                         21-01-0104-46   21-002
# 2                                         21-01-0106-46   21-004
# 3                                         21-01-0107-46   21-004
# 4                                         21-01-0108-46   21-004
# ...                                                 ...      ...
# 9395                                      16-17-0144-46   16-026
# 9396                                      16-17-0147-46   16-026
# 9397                                                NaN      NaN
# 9398                  374 Establecimientos encontrados       NaN
# 9399  alert('Ocurri󠵮 error!\n Thread was being abort...      NaN
#
#       DEPARTAMENTO MUNICIPIO  \
# 0           JALAPA    JALAPA
# 1           JALAPA    JALAPA
# 2           JALAPA    JALAPA
# 3           JALAPA    JALAPA
# 4           JALAPA    JALAPA
# ...            ...       ...
# 9395  ALTA VERAPAZ   RAXRUHA
# 9396  ALTA VERAPAZ   RAXRUHA
# 9397           NaN       NaN
# 9398           NaN       NaN
# 9399           NaN       NaN
#
#                                         ESTABLECIMIENTO  \
# 0     INSTITUTO NORMAL CENTROAMERICANO PARA SEяRITAS...
# 1         INSTITUTO NORMAL CENTROAMERICANO PARA VARONES
# 2                 COLEGIO PARTICULAR MIXTO LICEO JALAPA
# 3         INSTITUTO PARTICULAR MIXTO MODERNO JALAPANECO
# 4     INSTITUTO PRIVADO DE EDUCACION DIVERSIFICADA E...
# ...                                                 ...
# 9395  INSTITUTO MIXTO DE MAGISTERIO BILING܅ "SAN ANT...
# 9396  INSTITUTO MIXTO DE MAGISTERIO BILING܅ "SAN ANT...
# 9397                                                NaN
# 9398                                                NaN
# 9399                                                NaN
#
#                                               DIRECCION           TELEFONO  \
# 0                        AVENIDA CHIPILAPA 1-65, ZONA 2           79224268
# 1     CALLE TRANSITO ROJAS, 4-82, ZONA 2, BARRIO SAN...           40645842
# 2                      CALLE TRANSITO ROJAS 7-60 ZONA 1           79220013
# 3             3A. CALLE 0-39 ZONA 2 BARRIO LA ESPERANZA           51228253
# 4         4A. AVENIDA 2-66, ZONA 2 BARRIO SAN FRANCISCO  79224958-79223033
# ...                                                 ...                ...
# 9395                                  BARRIO SANTA MAŔ           40659805
# 9396                                 BARRIO SANTA MARIA           40659805
# 9397                                                NaN                NaN
# 9398                                                NaN                NaN
# 9399                                                NaN                NaN
#
#                           SUPERVISOR                         DIRECTOR  \
# 0          JORGE ADELINO PEREZ UCELO  IRIS JANNETTE AGUIRRE CONTRERAS
# 1          JORGE ADELINO PEREZ UCELO     LISI KARINA ESCOBAR ESPINOZA
# 2     VICTOR MANUEL PORTILLO RECINOS    EFRA͎ DE JESړ SALAZAR PERALTA
# 3     VICTOR MANUEL PORTILLO RECINOS      GERMAN DE JESUS RAMOS VALLE
# 4     VICTOR MANUEL PORTILLO RECINOS     ROSA CORALIA PINEDA GALLARDO
# ...                              ...                              ...
# 9395      ILEANA VERӎICA MACZ CALACH                    MATEO COC CUC
# 9396      ILEANA VERӎICA MACZ CALACH                    MATEO COC CUC
# 9397                             NaN                              NaN
# 9398                             NaN                              NaN
# 9399                             NaN                              NaN
#
#               NIVEL   SECTOR    AREA            STATUS   MODALIDAD  \
# 0     DIVERSIFICADO  OFICIAL  URBANA           ABIERTA  MONOLINGUE
# 1     DIVERSIFICADO  OFICIAL  URBANA           ABIERTA  MONOLINGUE
# 2     DIVERSIFICADO  PRIVADO  URBANA           ABIERTA  MONOLINGUE
# 3     DIVERSIFICADO  PRIVADO  URBANA  TEMPORAL TITULOS  MONOLINGUE
# 4     DIVERSIFICADO  PRIVADO  URBANA           ABIERTA  MONOLINGUE
# ...             ...      ...     ...               ...         ...
# 9395  DIVERSIFICADO  PRIVADO  URBANA           ABIERTA  MONOLINGUE
# 9396  DIVERSIFICADO  PRIVADO  URBANA           ABIERTA  MONOLINGUE
# 9397            NaN      NaN     NaN               NaN         NaN
# 9398            NaN      NaN     NaN               NaN         NaN
# 9399            NaN      NaN     NaN               NaN         NaN
#
#           JORNADA                            PLAN DEPARTAMENTAL
# 0      VESPERTINA                 DIARIO(REGULAR)        JALAPA
# 1        MATUTINA                 DIARIO(REGULAR)        JALAPA
# 2        NOCTURNA                 DIARIO(REGULAR)        JALAPA
# 3      VESPERTINA                 DIARIO(REGULAR)        JALAPA
# 4      VESPERTINA                 DIARIO(REGULAR)        JALAPA
# ...           ...                             ...           ...
# 9395        DOBLE                   FIN DE SEMANA  ALTA VERAPAZ
# 9396  SIN JORNADA  SEMIPRESENCIAL (FIN DE SEMANA)  ALTA VERAPAZ
# 9397          NaN                             NaN           NaN
# 9398          NaN                             NaN           NaN
# 9399          NaN                             NaN           NaN
#
# [9400 rows x 17 columns]

# %%
deptos = df['DEPARTAMENTO']

# %%
deptos = list(dict.fromkeys(deptos))
print(f"{len(deptos)} : {deptos}")
# Out:
# 24 : ['JALAPA', nan, 'SOLOLA', 'CHIMALTENANGO', 'EL PROGRESO', 'JUTIAPA', 'SANTA ROSA', 'SAN MARCOS', 'QUETZALTENANGO', 'ZACAPA', 'PETEN', 'HUEHUETENANGO', 'SUCHITEPEQUEZ', 'BAJA VERAPAZ', 'QUICHE', 'RETALHULEU', 'TOTONICAPAN', 'IZABAL', 'CIUDAD CAPITAL', 'ESCUINTLA', 'SACATEPEQUEZ', 'CHIQUIMULA', 'GUATEMALA', 'ALTA VERAPAZ']

# %%
# Inicializa un diccionario para almacenar el conteo de filas de cada archivo
file_row_counts = {}

# Recorre todos los archivos en el directorio
for filename in os.listdir(directorio):
    if filename.endswith(".csv"):
        filepath = os.path.join(directorio, filename)
        # Lee cada archivo CSV omitiendo la primera fila
        df = pd.read_csv(filepath, skiprows=1)
        # Elimina columnas "Unnamed"
        df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
        # Cuenta el número de filas y almacena el resultado en el diccionario
        file_row_counts[filename] = df.shape[0]

# Imprime el conteo de filas de cada archivo
for filename, row_count in file_row_counts.items():
    print(f"El archivo '{filename}' tiene {row_count} filas (excluyendo encabezados).")

print("¡Conteo de filas completado exitosamente!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 file_row_counts = {}
#       4 # Recorre todos los archivos en el directorio
# ----> 5 for filename in os.listdir(directorio):
#       6     if filename.endswith(".csv"):
#       7         filepath = os.path.join(directorio, filename)
#
# NameError: name 'os' is not defined
